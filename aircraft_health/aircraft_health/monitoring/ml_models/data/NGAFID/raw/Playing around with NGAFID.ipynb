# %%
# Import necessary libraries
import pandas as pd

# File paths (update these paths with the correct file locations)
flight_header_path = 'flight_header.csv'

# Load the CSV files
try:
    flight_header_df = pd.read_csv(flight_header_path)    
    # Display basic information about flight_header.csv
    print("### Flight Header CSV Info ###")
    print(flight_header_df.info())
    print("\nFirst 5 rows of flight_header.csv:")
    print(flight_header_df.head())
    print("\nDescription of numeric columns in flight_header.csv:")
    print(flight_header_df.describe())

except FileNotFoundError as e:
    print(f"File not found: {e}")
except pd.errors.EmptyDataError as e:
    print(f"File is empty: {e}")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# ### Flight Header CSV Info ###
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11446 entries, 0 to 11445
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Master Index           11446 non-null  int64
#  1   before_after           11446 non-null  int64
#  2   date_diff              11446 non-null  int64
#  3   flight_length          11446 non-null  float64
#  4   label                  11446 non-null  object
#  5   hierarchy              4110 non-null   object
#  6   fold                   11446 non-null  int64
#  7   class                  11446 non-null  int64
#  8   target_class           11446 non-null  int64
#  9   hclass                 11446 non-null  int64
#  10  number_flights_before  11446 non-null  int64
# dtypes: float64(1), int64(8), object(2)
# memory usage: 983.8+ KB
# None
#
# First 5 rows of flight_header.csv:
# ...

# %%
# Visualization of flight_header.csv and stats.csv
import matplotlib.pyplot as plt
import seaborn as sns

# Flight Length Distribution
sns.histplot(flight_header_df['flight_length'], kde=True)
plt.title('Flight Length Distribution')
plt.xlabel('Flight Length')
plt.ylabel('Frequency')
plt.show()

# Correlation Heatmap for stats.csv
plt.figure(figsize=(12, 10))
sns.heatmap(stats_df.corr(), annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Correlation Heatmap for Stats.csv')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 14
#      12 # Correlation Heatmap for stats.csv
#      13 plt.figure(figsize=(12, 10))
# ---> 14 sns.heatmap(stats_df.corr(), annot=True, fmt='.2f', cmap='coolwarm')
#      15 plt.title('Correlation Heatmap for Stats.csv')
#      16 plt.show()
#
# File c:\Users\Decartes\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\Decartes\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
# ...

# %%
# Additional Visualizations for flight_header.csv
import matplotlib.pyplot as plt
import seaborn as sns

# Distribution of 'label' column
plt.figure(figsize=(8, 6))
sns.countplot(data=flight_header_df, x='label')
plt.title('Distribution of Labels')
plt.xlabel('Label')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# Bar plot for 'before_after' column
plt.figure(figsize=(6, 4))
sns.countplot(data=flight_header_df, x='before_after')
plt.title('Before After Distribution')
plt.xlabel('Before After')
plt.ylabel('Count')
plt.show()

# Pair Plot for numerical columns in flight_header.csv
numeric_cols_fh = flight_header_df.select_dtypes(include=['int64', 'float64']).columns
sns.pairplot(flight_header_df[numeric_cols_fh])
plt.suptitle('Pair Plot of Numerical Columns in flight_header.csv', y=1.02)
plt.show()

# Additional Visualizations for stats.csv

# Box plots for selected numerical columns
selected_cols_stats = ['volt1', 'volt2', 'amp1', 'amp2', 'E1 RPM', 'OAT']
plt.figure(figsize=(12, 8))
sns.boxplot(data=stats_df[selected_cols_stats])
plt.title('Box Plots of Selected Numerical Columns in stats.csv')
plt.xlabel('Variables')
plt.ylabel('Values')
plt.show()

# Pair Plot for numerical columns in stats.csv
numeric_cols_stats = stats_df.select_dtypes(include=['int64', 'float64']).columns
sns.pairplot(stats_df[numeric_cols_stats])
plt.suptitle('Pair Plot of Numerical Columns in stats.csv', y=1.02)
plt.show()

# Heatmap of correlations in flight_header.csv
plt.figure(figsize=(10, 8))
sns.heatmap(flight_header_df.corr(), annot=True, cmap='viridis')
plt.title('Correlation Heatmap for flight_header.csv')
plt.show()

# Heatmap of correlations in stats.csv
plt.figure(figsize=(14, 12))
sns.heatmap(stats_df.corr(), annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Correlation Heatmap for stats.csv')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 47
#      45 # Heatmap of correlations in flight_header.csv
#      46 plt.figure(figsize=(10, 8))
# ---> 47 sns.heatmap(flight_header_df.corr(), annot=True, cmap='viridis')
#      48 plt.title('Correlation Heatmap for flight_header.csv')
#      49 plt.show()
#
# File c:\Users\Decartes\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\Decartes\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
# ...
